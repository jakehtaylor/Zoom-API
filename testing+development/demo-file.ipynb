# %%
import pandas as pd
import numpy as np
import random as rd
import names

# %%
logs = pd.read_csv('zoom_logs.csv', header=2)

# %%
Locs = logs['Location'].to_list()
Cams = logs['Camera'].to_list()
Speak = logs['Speaker'].to_list()

# %%
Mics = ['AT2005USB',
 'AT2020 USB','Auriculares con micrófono (Vorago HPB-601 Hands-Free AG Audio)',
 'Blue Snowball',
 'Blue Snowflake',
 'BluetoothHFP',
 'Budsies',
 'Built-in Microphone (External Microphone)',
 'Built-in Microphone (Internal Microphone)',
 'CarAudio','DTEN MIC ME 27',
 'Display Audio',
 'External Microphone (External Microphone)',
 'Grupo de microfones (Realtek High Definition Audio(SST))',
 'HAVIT I98',
 'HD Pro Webcam C920',
 'Headset (Bose On-Ear Wireless Hands-Free AG Audio)','Logitech USB Headset',
 'MacBook Air Microphone (MacBook Air Microphone)',
 'MacBook Pro Microphone (MacBook Pro Microphone)', 'Mic in at front panel (black) (Realtek High Definition Audio)',
 'Microfone (2- Plantronics USB Headset-UC)',
 'Microfone (3- USB2.0 MIC)',
 'Microfone (C922 Pro Stream Webcam)',
 'Microfone (HD Pro Webcam C920)',
 'Microfone (Realtek High Definition Audio)',
 'Microfone (Realtek(R) Audio)',
 'Microfono (Realtek High Definition Audio)',
 'Microphone (1080P Webcam)',
 'Microphone (2- Logitech USB Headset)',
 'Microphone (2- Realtek USB2.0 MIC)',
 'Microphone (Blue Snowball)',
 'Microphone (HD Webcam C270)',
 'Microphone (JOUNIVO JV601)',
 'Microphone (Jabra Link 370)',
 'Microphone (Live! Cam Sync HD VF0770)',
 'Microphone (Mpow HC)',
 'Microphone (Mpow-224)',
 'Microphone (Plantronics BT300)',
 'Microphone (Realtek Audio)',
 'Microphone (Realtek High Definition Audio)',
 'Microphone (Realtek(R) Audio)',
 'Microphone (Rode Podcaster)',]

# %%
IPs = []
for x in range(0,733):
    IP = "Public IP: " + str(rd.randint(10, 200)) +'.'+ str(rd.randint(1, 200))+'.'+ str(rd.randint(1, 200))+'.'+ str(rd.randint(1, 200)) + ' Local IP: ' + '0.0.0.0,'+ str(rd.randint(100, 200)) + '.' + str(rd.randint(10, 200)) + '.'+ str(rd.randint(1, 200)) + '.' + str(rd.randint(1, 999))
    IPs.append(IP)

# %%
MICs = []

for x in range(0,733):
    mic = Mics[rd.randint(0, len(Mics)-1)]
    MICs.append(mic)

# %%
len(MICs)
# Out:
# 733

# %%
CAMs = []
for x in range(0,733):
    cam = Cams[rd.randint(0, len(Cams)-1)]
    CAMs.append(cam)

# %%
len(CAMs)
# Out:
# 733

# %%
Speak = ['Altavoces (Realtek High Definition Audio)',
 'Altavoces (Realtek(R) Audio)',
 'Altavoces / Auriculares (Realtek High Definition Audio)',
 'Altavoz/Auricular (Realtek High Definition Audio)',
 'Alto-falantes (2- High Definition Audio Device)',
 'Alto-falantes (2- Plantronics USB Headset-UC)',
 'Alto-falantes (High Definition Audio Device)',
 'Alto-falantes (Realtek High Definition Audio(SST))',
 'Alto-falantes (Realtek(R) Audio)',
 'Alto-falantes/Fone de ouvido (Realtek High Definition Audio)',
 'Altofalantes (Realtek(R) Audio)',
 'Altoparlanti (Realtek High Definition Audio)',
 'Auriculares con micrófono (Vorago HPB-601 Hands-Free AG Audio)',
 'BluetoothHFP','Built-in Output (Headphones)',
 'Built-in Output (Internal Speakers)',
 'C27F591 (Intel(R) Display Audio)',
 'CarAudio','DELL C7017T (Intel(R) Display Audio)',
 'DELL U3818DW (DELL U3818DW)',
 'DTEN ME',
 'Display Audio',
 'E2241 (NVIDIA High Definition Audio)',
 'EPSON Projector Audio',
 'External Headphones (External Headphones)',
 'Fones de ouvido (Realtek(R) Audio)',
 'Fones de ouvido / Alto falantes (Realtek Audio)',
 'Fones de ouvido / Alto falantes (Realtek High Definition Audio)',
 'HAVIT I98',
 'HDMI (LG TV)',
 'Headphone (Realtek Audio)',
 'Headphones',
 'Headphones (Conexant ISST Audio)',
 'Headphones (Realtek High Definition Audio(SST))',
 'Headphones (ThinkPad Dock USB Audio)',
 'Headset (Bose On-Ear Wireless Hands-Free AG Audio)',
 'Headset (TOZO-T6 Hands-Free AG Audio)',
 'Headset Earphone (2- Plantronics BT300M)',
 'Headset Earphone (Jabra EVOLVE 20 SE MS)',
 'Headset Earphone (Microsoft LifeChat LX-3000)',
 'Headset Earphone (Plantronics Blackwire 5220 Series)','Speakers (2- Dell USB Audio)',
 'Speakers (2- Logitech USB Headset)',
 'Speakers (2- Realtek(R) Audio)',
 'Speakers (Conexant ISST Audio)',
 'Speakers (Dell AC511 USB SoundBar)',
 'Speakers (Dell USB Audio)',
 'Speakers (High Definition Audio Device)',
 'Speakers (Jabra Link 370)',
 'Speakers (Jabra SPEAK 510 USB)',
 'Speakers (Lexicon I-ONIX U42S 2.9.13)',
 'Speakers (Logitech USB Headset)',
 'Speakers (Microsoft Docking Station Audio Device)',
 'Speakers (Mpow HC)',
 'Speakers (Mpow-224)',
 'Speakers (Phnx MT202pcs)',
 'Speakers (Plantronics BT300)',
 'Speakers (Realtek High Definition Audio(SST))',
 'Speakers (Realtek High Definition Audio)',
 'Speakers (Realtek(R) Audio)',
]

# %%
SPKs = []
for x in range(0,733):
    spk = Speak[rd.randint(0, len(Speak)-1)]
    SPKs.append(spk)
len(SPKs)
# Out:
# 733

# %%
#SPKs, CAMs, MICs, IPs
LOCs = []
for x in range(0, 733):
    loc = Locs[rd.randint(0, len(Locs)-1)]
    LOCs.append(loc)
len(LOCs)
# Out:
# 733

# %%
#SPKs, CAMs, MICs, IPs, LOCs, DVCs

# %%
ogNames = set(logs['Participant'])
ogNames
# Out:
# {'A.J. Wood',
#  'ANDREW STONE',
#  'Adobe - Katie Pierce',
#  'Adobe EduMAX 2020',
#  'Adriana Higuera',
#  'Aimee Terosky (she/her)',
#  'Aja Bettencourt-McCarthy',
#  'Alex Cayaffa (Adobe)',
#  'Alissa Fairchild',
#  'Allison Hall',
#  'Allison Schumacher',
#  'Amber Hutchins',
#  'Amber Willenborg',
#  'Amelia Noel-Elkins',
#  'Amie Chavez-Aguilar',
#  'Amir Dabirian',
#  'Amos Gutierrez',
#  'Amy Tan',
#  'Ana Laura Gomes',
#  'Andre Lampkins',
#  'Andrea Olinger',
#  'Andressa Sily',
#  'Andrew Ilnicki',
#  'Andrew Shipka',
#  'Andrew Stone',
#  'Ann',
#  'Ann Kucera',
#  'Anna Jamieson',
#  'Anna Smith',
#  'Anthony Artimisi',
#  'Antionette Moore',
#  'Ateken Abla',
#  'Audra Carlisle',
#  'Barbara Boyan',
#  'Bart Pursel',
#  'Becki Hagen',
#  'Bobbie Garner-Coffie',
#  'Bobbie Shack',
#  'Bonnie Banks',
#  'Bradley Buchanan - Adobe',
#  'Brent Whiting',
#  'Brian Roberts',
#  'Brian Taylor',
#  'Bridget McNamara',
#  'CITI at WSSU',
#  'CORY STOKES',
#  'Caitlin',
# ...

# %%
impReps = {
    'Andrew Stone' : 'Peter Cline',
    'ANDREW STONE' : 'PETER CLINE',
    'Ann Kucera' : 'Sam Celeste',
    'Ann' : 'Sam',
    'Sanna' : 'Asama',
    "Caitlin Benallack (she/her/hers)" : "Roberta Gudmonson (she/her/hers)",
    'Caitlin' : 'Roberta',
    "dina vees" : 'lacy gumm',
    "Dina Vees" : 'Lacy Gumm',
    "erica.dalbello" : 'luigi.cabelito',
    "Erica DalBello" : 'Luigi Cabelito',
    "FelipeB" : 'ColtonK',
    "Felipe Benutti" : 'Colton Kidmann',
    "Gilberto" : "Marriana",
    "GILBERTO VIEIRA BRANCO" : "MARRIANA LUISAO CONTRO",
    "Jay Frye" : 'Ben Ymer',
    "Jay" : 'Ben',
    "jayfrye" : 'benymer',
    "Jennifer J." : "Nicholas R.",
    "Jennifer Doran" : "Nicholas Ronin",
    "Jennifer Friberg" : "Nicholas Jameson",
    "Jennifer Redd" : "Nicholas Penn",
    "Jennifer Shewmaker" : "Nicholas Shumacker",
    "Jennifer Sparrow" : "Nicholas Ravielo",
    "Jim Raber" : 'Kat Girde',
    "Jim R" : 'Kat G',
    "Jonathan Shaw" : 'Benjamin Prat',
    "Jonathan Lashley" : "Benjamin Helmley",
    "Justin Hodgson" : "Dustin Lannier",
    "Justin H" : "Dustin L",
    "justin.boudreau" : "dustin.woodrow",
    "Maureen Biggers- Indiana University" : "Kathleen Holland- Zoom University",
    "Maureen Biggers" : "Kathleen Holland",
    "Monica R." : "Archie J.",
    "Monica Badgley" : 'Archie Colbert',
    "Sara Bohmholdt" : "Jane Alexander",
    "Sara" : "Jane",
    "Sasha McQuaid" : "Hasan McQueen",
    "Sasha" : "Hasan",
    "Sebastian MC" : "Francisco NB",
    "SebastianMC" : "FranciscoNB",
    "Sebastian Distefano" : "Francisco Alaventa",
    "Stephanie Mathson" : "Elizabeth Hodgson",
    "Stephanie" : "Elizabeth",
    "vanessa cardozo" : "aaliyah saldana",
    "Vanessa Cardozo" : "Aaliyah Saldana",
    "A.J. Wood" : 'P.L. Cuye',
    "Adobe - Katie Pierce" : 'ZoomE - Jamie Cooper',
    "Adobe EduMAX 2020" : "Zoome Launch 2021",
    "Aimee Terosky (she/her)" : "Helen Trotsky (she/her)",
    "Aja Bettencourt-McCarthy" : "Eze Pippenserva-McCaplin",
    "Alex Cayaffa (Adobe)" : "Jake Luftwaffe (ZoomE)",
    "Amelia Noel-Elkins" : "Emily Cole-Watkins",
    "Amie Chavez-Aguilar" : "Emma Juarez-Soledad",
    "Bobbie Garner-Coffie" : "Johnny Warner-Smith",
    "Bradley Buchanan - Adobe" : "Johnson Mayfield - ZoomE",
    "DEBORAH KEYEK-FRANSSEN" : "Amelia Casek-Jonsson",
    "Dan O'Brien" : "Tim O'Leary",
    "Dana Williams-Johnson" : "Bono Timothy-Wilsonn",
    "Deborah J. Mateik" : "Amelia V. Makers",
    "Dennis J. Gajdos" : 'Emilio V. Garnon',
    "Doug P." : 'Jack F.',
    "Dr. Randi Archuleta" : "Dr. Patrick Gibraltar",
    "Ebony M. Sharper" : "Will C. Harpers",
    "Elliott Fraughton- University of Utah: Club U/Campus camps" : "Jameson Fredericks- University of Zoom: Club U/Campus camps",
    "Eng. Álvaro Venegas" : "Eng. Silvia Poderosa",
    "Jessica Phillips (she# her)" : "Cassandra Hamilton (she# her)",
    "Judith O'Dell" : "Garvey O'Malley",
    "Karen (she/her/hers) Pinto" : "Jamie (she/her/hers) Alinna",
    "Karina Branson | she# her" : "Patricia Hansen | she# her",
    "Kevin Bryant @ Adobe" : "Justin Lamar @ ZoomE",
    "Kirsten Nagel (Adobe)" : "Jennifer Maple (ZoomE)",
    "Lev Gonick(In-room Participants:-)": "Jim Hendrick(In-room Participants:-)",
    "M. Arq. Alfredo Ambriz" :  "M. Arq. Amerigo Gustavo",
    "Marian Holiday-White" : "Gonzolo Market-Smith",
    "Mary Z. Ashlock" : "Fran X. Whittier",
    "Matt Trevett-Smith" : 'Fred Humbert-Wilks',
    "Mayra - IPN" : "Katya - GCM",
    "Michael J Dangler - OSU" : "Jeremy E. Granger - RCU",
    "Michael Kala`i" : "Jeremy Bleuet",
    "Patrice Walker# NCCU" : 'Jericho Keller# GTCU',
    "Robert Teachenor (Miami Dade College)" :  "Indiana Morrisson (Zoom State College)",
    "Sean Foushee [AEL] Tarrant County College" : "Dane Cochrane [JNL] Zoom County College",
    "Stephen Cunetto# Miss State University" : "Elliot Manfredo# Zoom State University",
    "bianchi" : "chianta",
    "chren1km" : "trinh1kl",
    "dadair" : "brafiel",
    "hayesa.lewis" : "voyesb.chris",
    "ianbrown" : "jenwhite",
    "janethethorn" : "karenkristoph",
    "jillsolbes-camblong" : "toddgulbis-cameron",
    "jorge.gomez": "george.gomis",
    "paulinho" : 'cristiano',
    "scotthalle" : 'jamesgaule',
}

# %%
impRepNew = list(impReps.values())

# %%
impRepOg = list(impReps.keys())

# %%
remOgs = set(ogNames) - set(impRepOg)

# %%
logs.replace(impReps, inplace=True)

# %%
def genName():
    newName = names.get_full_name()
    if newName not in set(logs['Participant']):
        return newName
    else:
        genName()

remReps = {}
for name in remOgs:
    remReps[name] = genName()
# Out:
# {'Vitalina Nova': 'Roosevelt Long',
#  'Tiffany': 'Dwayne Martinez',
#  'Jill Alexander': 'Kayce Bishop',
#  'Stephen Hart': 'Terry Oneal',
#  'Sepideh Nia': 'Louis Johns',
#  'Mark Caruso': 'Lauren Hoisington',
#  'Jason Dojc': 'Brenda Ho',
#  'Tom Reichert': 'Cary Booker',
#  'Jan Holmevik': 'Maria Scarborough',
#  'Lourdes Gabrielli': 'Lawrence Zuniga',
#  'Amber Hutchins': 'Robert Escobar',
#  'Deloris Foxworth': 'Gerard Rasmussen',
#  'Patrick Charlton': 'Anthony Guajardo',
#  'James Wiser': 'Rachael Highland',
#  'Vicky Morris': 'James Ragsdale',
#  'Fiona Diec': 'Steven Smith',
#  'Jeremiah Shipp': 'Timothy Brown',
#  'Russell Brady': 'Corey Shaw',
#  'Joy Polefrone': 'Ernest Fallon',
#  'Tony Sams': 'Jeffrey Nunn',
#  'Tacy Trowbridge': 'Corey Brown',
#  'Manju Bhat': 'Ruth Blandford',
#  'Luis Ham': 'Trent Lewis',
#  'Chelsy Hooper': 'Maria Badgett',
#  'Frances M': 'Alfred Shankle',
#  'Thomas La Foe': 'Minnie Metayer',
#  'Professor Taylor': 'Allen Albano',
# ...

# %%
logs.replace(remReps, inplace=True)

# %%
#SPKs, CAMs, MICs, IPs, LOCs
logs['IP Address'] = IPs
logs['Location'] = LOCs
logs['Microphone'] = MICs
logs['Speaker'] = SPKs
logs['Camera'] = CAMs

# %%
demo_data1 = logs.to_csv('demo_data_1.csv')

# %%
for k in impReps:
    logs['Leave Time'] = logs['Leave Time'].str.replace(k, impReps[k], case=True)
    
for k in remReps:
    logs['Leave Time'] = logs['Leave Time'].str.replace(k, remReps[k], case=True)

# %%
x = '05:04 PM(Archie Colbert left the meeting.Reason: left the meeting.)'

half = x.split('M(')[0] + 'M(' + 'Archie Colbert'
if ' left ' in x:
    full = half + ' left ' + x.split(' left ')[1] + ' left ' + x.split(' left ')[2]
else
full
# Out:
# '05:04 PM(Archie Colbert left the meeting.Reason: left the meeting.)'

# %%
demo_data_2 = logs.to_csv('demo_data_v2.csv')

# %%
parens = [name for name in impReps if "(" in name]
vs = [impReps[p] for p in parens]
parens, vs
# Out:
# (['Caitlin Benallack (she/her/hers)',
#   'Aimee Terosky (she/her)',
#   'Alex Cayaffa (Adobe)',
#   'Jessica Phillips (she# her)',
#   'Karen (she/her/hers) Pinto',
#   'Kirsten Nagel (Adobe)',
#   'Lev Gonick(In-room Participants:-)',
#   'Robert Teachenor (Miami Dade College)'],
#  ['Roberta Gudmonson (she/her/hers)',
#   'Helen Trotsky (she/her)',
#   'Jake Luftwaffe (ZoomE)',
#   'Cassandra Hamilton (she# her)',
#   'Jamie (she/her/hers) Alinna',
#   'Jennifer Maple (ZoomE)',
#   'Jim Hendrick(In-room Participants:-)',
#   'Indiana Morrisson (Zoom State College)'])

# %%
leaveNames = [x.split('M(')[1].split(' left')[0].split(' got')[0] for x in logs['Leave Time']]

# %%
set(set(leaveNames) - set(impRepNew)) - set(list(remReps.values()))
# Out:
# {'Aimee Terosky (she/her)',
#  'Alex Cayaffa (Adobe)',
#  'Evelyn Keeton Lee',
#  'Jessica Phillips (she# her)',
#  'Karen (she/her/hers) Pinto',
#  'Kirsten Nagel (Adobe)',
#  'Lev Gonick',
#  'Patricia Hansen |Patricia Hansen | she# her|Patricia Hansen |Patricia Hansen | she# her',
#  'Robert Teachenor (Miami Dade College)',
#  'Roberto Benallack (she/her/hers)',
#  'Sama Jamieson',
#  'Sama Smith',
#  'Sean Foushee [AEL] Tarrant County College',
#  'Stella Wellsard Bernier',
#  'Stella Wellsard Burbank',
#  'Stella Wellsard Moore',
#  'Stella Wellsard Plamondon',
#  'Stella Wellsard Sandau',
#  'Stella Wellsard Schwald',
#  'Tamra Stella Wellsmond',
#  'William Stella Wellsardson'}
